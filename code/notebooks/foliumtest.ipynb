# %%
import folium
from LWR_Model import distances
distance, time, geo = distances.walk_lat_long(51.507351, -0.127758, 51.509865, -0.118853)
geo
route = []
for i in geo:
    j= i[0]
    k = i[1]
    route.append((j,k))

# %%
m = folium.Map(location=(53.464392, -2.231914))
folium.PolyLine(route).add_to(m)

# %%
m
