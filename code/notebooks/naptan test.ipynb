# %%
from lwr_model import get_naptan_data, LOCALITY_NAMES, ROAD_NAMES, BEARINGS

df = get_naptan_data()
df = df[df['LocalityName'].isin(LOCALITY_NAMES)]
df = df[df['Street'].isin(ROAD_NAMES)]
df = df[df['Status'] == 'active']
df = df[df['Bearing'].isin(BEARINGS)]
# df = df[df.drop_duplicates(subset=['ShortCommonName'])]
df = df[['NaptanCode', 'Latitude', 'Longitude', 'ShortCommonName', 'Bearing', 'LocalityName', 'Street']]
df
# Out:
#       NaptanCode   Latitude  Longitude  ShortCommonName Bearing  \
# 597     MANADWDP  53.454170  -2.224595  Grandale Street       N
# 601     MANADWGD  53.450830  -2.221770         Platt Ln       N
# 10815   MANGPGWM  53.470932  -2.237895       All Saints      NW
# 10817   MANGPGWT  53.470460  -2.237606       All Saints      NW
# 11122   MANTGJPT  53.440570  -2.219646   Friendship Inn       N
# 11166   MANGTGMJ  53.437010  -2.223767         Derby Rd      NE
# 11252   MANTWPMD  53.458566  -2.227480        St Mary's       N
# 11254   MANTWPTG  53.461556  -2.229092  Royal Infirmary       N
# 11257   MANTWPWJ  53.464613  -2.232165       University      NW
# 11258   MANTWPWM  53.467316  -2.234742  Shopping Centre      NW
# 11295   MANGTMGT  53.467531  -2.234924  Shopping Centre      NW
# 11297   MANGTMJA  53.464392  -2.231914       University      NW
# 11299   MANGTMJG  53.461960  -2.229411  Royal Infirmary       N
# 11301   MANGTMJP  53.458926  -2.227632        St Mary's       N
# ...
